# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook
import pandas as pd
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cd819f96-60c6-44af-b1c1-5c024c64d06c">Loading BokehJS ...</span>
#     </div>

# %%
np.set_printoptions(formatter={'float': lambda x: "{0:0.2f}".format(x)})
t = np.arange(0.01, 10*np.pi, .01)
x = t*np.sin(t)
print("t =",t)
print("x =",x)
p=figure()
p.line(t,x)
show(p)
# Out:
# t = [0.01 0.02 0.03 ... 31.39 31.40 31.41]
# x = [0.00 0.00 0.00 ... -0.81 -0.50 -0.19]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5786a6fe-51ff-4c0b-9766-4f9e75ef6ae6"></div>
# </div>

# %%
tau = 160
p=figure()
p.line(x[:-2*tau], x[tau:-tau])
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="26c0cb83-ff1a-4466-8786-e1dedc1269ac"></div>
# </div>

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
tau = 160
ax.plot(x[:-int(1.5*tau)], x[tau:-int(0.5*tau)], zs=x[int(1.5*tau):])

# %%
#from mpl_toolkits.mplot3d import Axes3D
#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#tau = 50
#ax.plot(x[:-2*tau], x[tau:-tau], zs=x[2*tau:])

# %%
t = np.arange(0.01, 10*np.pi, .01)
x = np.sin(1/t)
p=figure()
p.line(t,x)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c911b248-4fcd-46e7-8dd2-d4659ed80ed0"></div>
# </div>

# %%
tau = 150
p=figure()
p.line(x[:-tau], x[tau:])
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5ead0aef-69d2-46f9-ae59-d5c37813fadd"></div>
# </div>

# %%
x = np.tan(t)
#plt.plot(x)
p=figure()
p.line(x[:-tau], x[tau:])
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6959fc57-c29c-42ed-a01f-a9378124d9f6"></div>
# </div>
